# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def display(img, cmap='gray'):
    fig = plt.figure(figsize=(12,10))
    ax = fig.add_subplot(111)
    ax.imshow(img,cmap='gray')

# %%
reeses = cv2.imread('Desktop/DATA/reeses_puffs.png',0)

# %%
display(reeses)

# %%
cereals = cv2.imread('Desktop/DATA/many_cereals.jpg',0)

# %%
display(cereals)

# %%
orb = cv2.ORB_create()

# %%
kp1,des1 =orb.detectAndCompute(reeses,None)

# %%
kp2,des2 =orb.detectAndCompute(crereals,None)

# %%
bf = cv2.BFMatcher(cv2.NORM_HAMMING , crossCheck =True)

# %%
matches = bf.match(des1,des2)

# %%
matches
# Out:
# [<DMatch 000001489806CAD0>,
#  <DMatch 000001489806C830>,
#  <DMatch 000001489806CAB0>,
#  <DMatch 000001489806C6F0>,
#  <DMatch 000001489806C4D0>,
#  <DMatch 00000148980795D0>,
#  <DMatch 0000014898079990>,
#  <DMatch 000001489806CBB0>,
#  <DMatch 0000014898079510>,
#  <DMatch 000001489806C970>,
#  <DMatch 0000014898079470>,
#  <DMatch 0000014898079690>,
#  <DMatch 000001489806C210>,
#  <DMatch 000001489806CC50>,
#  <DMatch 00000148980793B0>,
#  <DMatch 000001489806C1D0>,
#  <DMatch 000001489806C2B0>,
#  <DMatch 000001489806C710>,
#  <DMatch 000001489806C9D0>,
#  <DMatch 000001489806CCD0>,
#  <DMatch 000001489806C730>,
#  <DMatch 0000014898079550>,
#  <DMatch 0000014898079570>,
#  <DMatch 000001489806C310>,
#  <DMatch 000001489806CCB0>,
#  <DMatch 000001489806C050>,
#  <DMatch 000001489806CB90>,
#  <DMatch 0000014898079910>,
#  <DMatch 0000014898079AD0>,
#  <DMatch 0000014898079A50>,
#  <DMatch 000001489806C650>,
#  <DMatch 000001489806CAF0>,
#  <DMatch 000001489806CE30>,
#  <DMatch 000001489806C230>,
#  <DMatch 0000014898079830>,
#  <DMatch 000001489806C110>,
#  <DMatch 000001489806C250>,
#  <DMatch 000001489806C770>,
#  <DMatch 000001489806CE10>,
#  <DMatch 000001489806CEF0>,
#  <DMatch 00000148980799B0>,
#  <DMatch 000001489806C370>,
#  <DMatch 000001489806CBD0>,
#  <DMatch 000001489806CF30>,
#  <DMatch 0000014898079170>,
#  <DMatch 00000148980791F0>,
#  <DMatch 0000014898079BB0>,
#  <DMatch 000001489806C1F0>,
#  <DMatch 000001489806CB70>,
#  <DMatch 0000014898079190>,
#  <DMatch 0000014898079450>,
#  <DMatch 000001489806C070>,
#  <DMatch 000001489806C3F0>,
#  <DMatch 000001489806C790>,
#  <DMatch 000001489806CD90>,
#  <DMatch 0000014898079030>,
#  <DMatch 00000148980792D0>,
#  <DMatch 000001489806C0F0>,
#  <DMatch 000001489806C130>,
#  <DMatch 000001489806CFB0>,
#  <DMatch 0000014898079390>,
#  <DMatch 0000014898079950>,
#  <DMatch 000001489806C7B0>,
#  <DMatch 000001489806C990>,
#  <DMatch 000001489806CA70>,
#  <DMatch 000001489806CD30>,
#  <DMatch 0000014898079070>,
#  <DMatch 0000014898079150>,
#  <DMatch 00000148980792B0>,
#  <DMatch 00000148980794F0>,
#  <DMatch 0000014898079870>,
#  <DMatch 0000014898079AF0>,
#  <DMatch 0000014898079CD0>,
#  <DMatch 00000148980781D0>,
#  <DMatch 000001489806C170>,
#  <DMatch 000001489806C930>,
#  <DMatch 000001489806CDD0>,
#  <DMatch 0000014898079A90>,
#  <DMatch 000001489806C350>,
#  <DMatch 000001489806C610>,
#  <DMatch 000001489806CB30>,
#  <DMatch 0000014898079090>,
#  <DMatch 0000014898079310>,
#  <DMatch 0000014898079B90>,
#  <DMatch 0000014898079C90>,
#  <DMatch 0000014898079F90>,
#  <DMatch 000001489806C2F0>,
#  <DMatch 000001489806C3B0>,
#  <DMatch 000001489806C450>,
#  <DMatch 000001489806C5B0>,
#  <DMatch 000001489806C8B0>,
#  <DMatch 000001489806CCF0>,
#  <DMatch 000001489806CE50>,
#  <DMatch 0000014898079250>,
#  <DMatch 0000014898079270>,
#  <DMatch 00000148980792F0>,
#  <DMatch 0000014898079850>,
#  <DMatch 0000014898079970>,
#  <DMatch 0000014898079B50>,
#  <DMatch 0000014898079C50>,
#  <DMatch 00000148980791D0>,
#  <DMatch 0000014898079610>,
#  <DMatch 00000148980796B0>,
#  <DMatch 0000014898079ED0>,
#  <DMatch 0000014898079F30>,
#  <DMatch 000001489806C3D0>,
#  <DMatch 000001489806C590>,
#  <DMatch 000001489806CEB0>,
#  <DMatch 0000014898079050>,
#  <DMatch 0000014898079530>,
#  <DMatch 0000014898079930>,
#  <DMatch 0000014898079DF0>,
#  <DMatch 000001489806C0D0>,
#  <DMatch 000001489806C330>,
#  <DMatch 000001489806C490>,
#  <DMatch 000001489806C510>,
#  <DMatch 000001489806C530>,
#  <DMatch 000001489806CB10>,
#  <DMatch 000001489806CC10>,
#  <DMatch 000001489806CC90>,
#  <DMatch 000001489806CD50>,
#  <DMatch 000001489806CE70>,
#  <DMatch 0000014898079330>,
#  <DMatch 00000148980796D0>,
#  <DMatch 00000148980781B0>,
#  <DMatch 000001489806C5F0>,
#  <DMatch 00000148980794D0>,
#  <DMatch 0000014898079770>,
#  <DMatch 000001489806C290>,
#  <DMatch 000001489806C810>,
#  <DMatch 000001489806C910>,
#  <DMatch 000001489806CBF0>,
#  <DMatch 00000148980795F0>,
#  <DMatch 00000148980797B0>,
#  <DMatch 0000014898079B70>,
#  <DMatch 0000014898079E30>,
#  <DMatch 0000014898079F70>,
#  <DMatch 0000014898078130>,
#  <DMatch 000001489806C7D0>,
#  <DMatch 000001489806C850>,
#  <DMatch 000001489806CDF0>,
#  <DMatch 0000014898079210>,
#  <DMatch 0000014898079410>,
#  <DMatch 00000148980799D0>,
#  <DMatch 000001489806C430>,
#  <DMatch 000001489806C6D0>,
#  <DMatch 000001489806C950>,
#  <DMatch 000001489806CC70>,
#  <DMatch 0000014898079130>,
#  <DMatch 00000148980797F0>,
#  <DMatch 0000014898079AB0>,
#  <DMatch 0000014898079B30>,
#  <DMatch 000001489806C470>,
#  <DMatch 000001489806C4B0>,
#  <DMatch 000001489806C8F0>,
#  <DMatch 000001489806CED0>,
#  <DMatch 0000014898079350>,
#  <DMatch 0000014898079370>,
#  <DMatch 0000014898079430>,
#  <DMatch 0000014898079750>,
#  <DMatch 0000014898079B10>,
#  <DMatch 000001489806C190>,
#  <DMatch 000001489806C390>,
#  <DMatch 000001489806CA90>,
#  <DMatch 000001489806CC30>,
#  <DMatch 000001489806CDB0>,
#  <DMatch 000001489806CF90>,
#  <DMatch 000001489806CFD0>,
#  <DMatch 00000148980793F0>,
#  <DMatch 0000014898078050>,
#  <DMatch 000001489806CF10>,
#  <DMatch 000001489806CF50>,
#  <DMatch 0000014898079810>,
#  <DMatch 00000148980798F0>,
#  <DMatch 0000014898079D30>,
#  <DMatch 0000014898079D50>,
#  <DMatch 0000014898078170>,
#  <DMatch 0000014898078210>,
#  <DMatch 000001489806C270>,
#  <DMatch 0000014898079110>,
#  <DMatch 0000014898079490>,
#  <DMatch 00000148980796F0>,
#  <DMatch 0000014898079C30>,
#  <DMatch 0000014898078030>,
#  <DMatch 0000014898078070>,
#  <DMatch 00000148980780B0>,
#  <DMatch 000001489806C410>,
#  <DMatch 000001489806C550>,
#  <DMatch 000001489806C630>,
#  <DMatch 00000148980794B0>,
#  <DMatch 0000014898079710>,
#  <DMatch 0000014898079A10>,
#  <DMatch 0000014898079BD0>,
#  <DMatch 0000014898079DD0>,
#  <DMatch 0000014898078090>,
#  <DMatch 00000148980780D0>,
#  <DMatch 000001489806C2D0>,
#  <DMatch 000001489806C570>,
#  <DMatch 000001489806C670>,
#  <DMatch 000001489806C6B0>,
#  <DMatch 000001489806CD70>,
#  <DMatch 000001489806CE90>,
#  <DMatch 00000148980791B0>,
#  <DMatch 0000014898079630>,
#  <DMatch 0000014898079A70>,
#  <DMatch 0000014898078190>,
#  <DMatch 0000014898079290>,
#  <DMatch 00000148980793D0>,
#  <DMatch 0000014898079650>,
#  <DMatch 0000014898079670>,
#  <DMatch 0000014898079730>,
#  <DMatch 0000014898079890>,
#  <DMatch 00000148980798D0>,
#  <DMatch 0000014898079A30>,
#  <DMatch 0000014898079DB0>,
#  <DMatch 0000014898079FB0>,
#  <DMatch 0000014898078110>,
#  <DMatch 0000014898078150>,
#  <DMatch 000001489806C690>,
#  <DMatch 000001489806CA30>,
#  <DMatch 0000014898079230>,
#  <DMatch 00000148980797D0>,
#  <DMatch 0000014898079D90>,
#  <DMatch 0000014898079E50>,
#  <DMatch 0000014898079EB0>,
#  <DMatch 00000148980781F0>,
#  <DMatch 000001489806C750>,
#  <DMatch 000001489806C890>,
#  <DMatch 000001489806C9B0>,
#  <DMatch 00000148980790B0>,
#  <DMatch 00000148980790D0>,
#  <DMatch 00000148980790F0>,
#  <DMatch 00000148980795B0>,
#  <DMatch 0000014898079D10>,
#  <DMatch 0000014898079E70>,
#  <DMatch 000001489806C9F0>,
#  <DMatch 00000148980799F0>,
#  <DMatch 0000014898079C70>,
#  <DMatch 0000014898079F50>,
#  <DMatch 000001489806C870>,
#  <DMatch 000001489806CA10>,
#  <DMatch 000001489806CF70>,
#  <DMatch 0000014898079590>,
#  <DMatch 0000014898079790>,
#  <DMatch 0000014898079FD0>,
#  <DMatch 000001489806C4F0>,
#  <DMatch 000001489806C7F0>,
#  <DMatch 000001489806CD10>,
#  <DMatch 00000148980798B0>,
#  <DMatch 0000014898079CB0>,
#  <DMatch 000001489806C8D0>,
#  <DMatch 000001489806CB50>,
#  <DMatch 0000014898079CF0>,
#  <DMatch 00000148980780F0>,
#  <DMatch 0000014898079EF0>,
#  <DMatch 0000014898079F10>,
#  <DMatch 0000014898079BF0>,
#  <DMatch 0000014898079D70>,
#  <DMatch 0000014898079E90>,
#  <DMatch 0000014898079C10>,
#  <DMatch 0000014898079E10>,
#  <DMatch 000001489806CA50>,
#  <DMatch 000001489806C5D0>]

# %%
single_match = matches[0]

# %%
#how good is the match
single_match.distance
# Out:
# 44.0

# %%
matches = sorted(matches, key = lambda x:x.distance)

# %%
reeses_matches = cv2.drawMatches(reeses, kp1, cereals, kp2 , matches[:25],None, flags =2 )

# %%
display(reeses_matches)
