# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
flat_chess = cv2.imread('Desktop/DATA/flat_chessboard.png')
flat_chess = cv2.cvtColor(flat_chess,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(flat_chess)

# %%
gray_flat_chess =  cv2.cvtColor(flat_chess , cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray_flat_chess, cmap ='gray')

# %%
real_chess = cv2.imread('Desktop/DATA/real_chessboard.jpg')
real_chess = cv2.cvtColor(real_chess,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(real_chess)

# %%
gray_real_chess =  cv2.cvtColor(real_chess, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_real_chess , cmap ='gray')

# %%
gray_flat_chess
# Out:
# array([[197, 197, 197, ..., 127, 127, 127],
#        [197, 197, 197, ..., 127, 127, 127],
#        [197, 197, 197, ..., 127, 127, 127],
#        ...,
#        [127, 127, 127, ..., 197, 197, 197],
#        [127, 127, 127, ..., 197, 197, 197],
#        [127, 127, 127, ..., 197, 197, 197]], dtype=uint8)

# %%
gray = np.float32(gray_flat_chess)

# %%
gray
# Out:
# array([[197., 197., 197., ..., 127., 127., 127.],
#        [197., 197., 197., ..., 127., 127., 127.],
#        [197., 197., 197., ..., 127., 127., 127.],
#        ...,
#        [127., 127., 127., ..., 197., 197., 197.],
#        [127., 127., 127., ..., 197., 197., 197.],
#        [127., 127., 127., ..., 197., 197., 197.]], dtype=float32)

# %%
dst = cv2.cornerHarris(src=gray,blockSize=2,ksize=3,k=0.04 )

# %%
dst = cv2.dilate(dst, None)

# %%
flat_chess[dst> 0.01*dst.max()] = [255,0,0]

# %%
plt.imshow(flat_chess)

# %%
gray = np.float32(gray_real_chess)
dst = cv2.cornerHarris(src=gray,blockSize=2,ksize=3,k=0.04 )

# %%
cv2.dilate(dst,None)
# Out:
# array([[  228.35156,   294.59958,   294.59958, ...,   751.76   ,
#           751.76   ,   440.1637 ],
#        [  228.35156,   294.59958,   294.59958, ...,   751.76   ,
#           751.76   ,   440.1637 ],
#        [  228.35156,  1067.0392 ,  1067.0392 , ...,   751.76   ,
#           751.76   ,   440.1637 ],
#        ...,
#        [20032.086  , 20032.086  , 20032.086  , ...,   843.64844,
#           843.64844,   843.64844],
#        [34144.785  , 34144.785  , 34144.785  , ...,   843.64844,
#           843.64844,   843.64844],
#        [34144.785  , 34144.785  , 34144.785  , ...,   662.5147 ,
#           662.5147 ,   662.5147 ]], dtype=float32)

# %%
real_chess[dst> 0.01*dst.max()] = [255,0,0]

# %%
plt.imshow(real_chess)

# %%
flat_chess = cv2.imread('Desktop/DATA/flat_chessboard.png')
flat_chess = cv2.cvtColor(flat_chess,cv2.COLOR_BGR2RGB)

real_chess = cv2.imread('Desktop/DATA/real_chessboard.jpg')
real_chess = cv2.cvtColor(real_chess,cv2.COLOR_BGR2RGB)

gray_flat_chess =  cv2.cvtColor(flat_chess, cv2.COLOR_BGR2GRAY)
gray_real_chess =  cv2.cvtColor(real_chess, cv2.COLOR_BGR2GRAY)

# %%
corners =  cv2.goodFeaturesToTrack(gray_flat_chess,5,0.01,10)

# %%
corners = np.int0(corners)

# %%
for i in corners:
    x,y = i.ravel()
    cv2.circle(flat_chess, (x,y), 3, (255,0,0), -1)

# %%
plt.imshow(flat_chess)

# %%
corners =  cv2.goodFeaturesToTrack(gray_real_chess,64,0.01,10)

# %%
corners =  np.int0(corners)

# %%
for i in corners:
    x,y = i.ravel()
    cv2.circle(real_chess, (x,y), 3, (255,0,0), -1)

# %%
plt.imshow(real_chess)
