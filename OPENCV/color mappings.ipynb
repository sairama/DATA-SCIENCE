# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img =cv2.imread('Desktop/DATA/00-puppy.jpg')

# %%
plt.imshow(img)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
plt.imshow(img)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2HLS)
plt.imshow(img)
